# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import sys
import os

import mysql.connector
from mysql.connector import Error

# %%
try:
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    current_dir = os.getcwd()

src_dir = os.path.join(current_dir, '../src')
sys.path.append(os.path.abspath(src_dir))

# %%
import clean

# %%
df = clean.import_data(data_path='../data')
df = clean.clean_data(df)
df
# Out:
# File 1: (445827, 65)
# File 2: (423889, 65)
# File 3: (479122, 65)
# File 4: (479950, 65)
# File 5: (479358, 65)
# File 6: (487637, 65)
# File 7: (502457, 65)
# File 8: (498347, 65)
# File 9: (454878, 65)
# File 10: (472626, 65)
# File 11: (450938, 65)
# File 12: (460949, 65)
# Dropping ['Unnamed: 64', 'UNIQUE_CARRIER', 'YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'DEP_TIME_BLK', 'ARR_TIME_BLK', 'CANCELLATION_CODE', 'FLIGHTS', 'DEP_DELAY_NEW', 'ARR_DELAY_NEW', 'DEP_DEL15', 'ARR_DEL15', 'FIRST_DEP_TIME', 'TOTAL_ADD_GTIME', 'LONGEST_ADD_GTIME']
# Dropping few problematic lines
# Dropping few Nan in ['CRS_ARR_TIME', 'CANCELLED', 'DIVERTED', 'CRS_ELAPSED_TIME', 'DISTANCE', 'DISTANCE_GROUP']
# Converting FL_DATE to datetime
# Converting columns to Int
#            FL_DATE  AIRLINE_ID CARRIER TAIL_NUM  FL_NUM  ORIGIN_AIRPORT_ID  \
# 0       2016-01-06       19805      AA   N4YBAA      43              11298
# 1       2016-01-07       19805      AA   N434AA      43              11298
# 2       2016-01-08       19805      AA   N541AA      43              11298
# 3       2016-01-09       19805      AA   N489AA      43              11298
# 4       2016-01-10       19805      AA   N439AA      43              11298
# ...            ...         ...     ...      ...     ...                ...
# 5635973 2016-12-31       19393      WN   N7703A    1077              15376
# 5635974 2016-12-31       19393      WN   N7815L    1345              15376
# 5635975 2016-12-31       19393      WN   N967WN    1176              15376
# 5635976 2016-12-31       19393      WN   N271LV     865              15376
# 5635977 2016-12-31       19393      WN   N762SW    6775              15376
#
#          ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID ORIGIN  \
# 0                      1129804                  30194    DFW
# 1                      1129804                  30194    DFW
# 2                      1129804                  30194    DFW
# 3                      1129804                  30194    DFW
# 4                      1129804                  30194    DFW
# ...                        ...                    ...    ...
# 5635973                1537602                  30436    TUS
# 5635974                1537602                  30436    TUS
# 5635975                1537602                  30436    TUS
# 5635976                1537602                  30436    TUS
# 5635977                1537602                  30436    TUS
#
#               ORIGIN_CITY_NAME  ... CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  \
# 0        Dallas/Fort Worth, TX  ...              158                  155
# 1        Dallas/Fort Worth, TX  ...              158                  150
# 2        Dallas/Fort Worth, TX  ...              158                  170
# 3        Dallas/Fort Worth, TX  ...              158                  151
# 4        Dallas/Fort Worth, TX  ...              158                  171
# ...                        ...  ...              ...                  ...
# 5635973             Tucson, AZ  ...               95                   90
# 5635974             Tucson, AZ  ...               95                   99
# 5635975             Tucson, AZ  ...              200                  176
# 5635976             Tucson, AZ  ...               75                   72
# 5635977             Tucson, AZ  ...               80                   73
#
#         AIR_TIME  DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  \
# 0            132       986               4           <NA>           <NA>
# 1            126       986               4           <NA>           <NA>
# 2            135       986               4           <NA>           <NA>
# 3            129       986               4           <NA>           <NA>
# 4            137       986               4              0              0
# ...          ...       ...             ...            ...            ...
# 5635973       69       451               2           <NA>           <NA>
# 5635974       73       451               2           <NA>           <NA>
# 5635975      163      1440               6           <NA>           <NA>
# 5635976       58       368               2           <NA>           <NA>
# 5635977       59       368               2           <NA>           <NA>
#
#         NAS_DELAY SECURITY_DELAY LATE_AIRCRAFT_DELAY
# 0            <NA>           <NA>                <NA>
# 1            <NA>           <NA>                <NA>
# 2            <NA>           <NA>                <NA>
# 3            <NA>           <NA>                <NA>
# 4              47              0                  66
# ...           ...            ...                 ...
# 5635973      <NA>           <NA>                <NA>
# 5635974      <NA>           <NA>                <NA>
# 5635975      <NA>           <NA>                <NA>
# 5635976      <NA>           <NA>                <NA>
# 5635977      <NA>           <NA>                <NA>
#
# [5635967 rows x 47 columns]

# %%
df.columns.to_list()
# Out:
# ['FL_DATE',
#  'AIRLINE_ID',
#  'CARRIER',
#  'TAIL_NUM',
#  'FL_NUM',
#  'ORIGIN_AIRPORT_ID',
#  'ORIGIN_AIRPORT_SEQ_ID',
#  'ORIGIN_CITY_MARKET_ID',
#  'ORIGIN',
#  'ORIGIN_CITY_NAME',
#  'ORIGIN_STATE_ABR',
#  'ORIGIN_STATE_FIPS',
#  'ORIGIN_STATE_NM',
#  'ORIGIN_WAC',
#  'DEST_AIRPORT_ID',
#  'DEST_AIRPORT_SEQ_ID',
#  'DEST_CITY_MARKET_ID',
#  'DEST',
#  'DEST_CITY_NAME',
#  'DEST_STATE_ABR',
#  'DEST_STATE_FIPS',
#  'DEST_STATE_NM',
#  'DEST_WAC',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'DEP_DELAY_GROUP',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'ARR_DELAY_GROUP',
#  'CANCELLED',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'DISTANCE_GROUP',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY']

# %% [markdown]
# ## Connect to mysql

# %%
def connect_to_database(database, host='localhost', user='root', password='password', v=True):
    try:
        connection = mysql.connector.connect(
            host=host,
            database=database,
            user=user,
            password=password
        )
        
        if connection.is_connected():
            db_info = connection.get_server_info()
            if v:
                print("Connected to MySQL Server version", db_info)
            cursor = connection.cursor()
            cursor.execute("select database();")
            record = cursor.fetchone()
            if v:
                print("You're connected to database:", record)
            return connection, cursor

    except Error as e:
        if v: 
            print("Error while connecting to MySQL", e)

    return None

# %%
def close_connection(connection, cursor):
    if cursor:
        cursor.close()
    if connection and connection.is_connected():
        connection.close()
        print("MySQL connection is closed")

# %%
con, cur = connect_to_database('scopa')
# Out:
# Connected to MySQL Server version 8.3.0
# You're connected to database: ('scopa',)

# %%
# close_connection(con, cur)
# Out:
# MySQL connection is closed

# %%
def show_databases(connection):
    cursor = None
    try:
        cursor = connection.cursor()
        cursor.execute("SHOW DATABASES")
        databases = cursor.fetchall()
        print("Databases:")
        for database in databases:
            print(database[0])  # Print the database name
    except Error as e:
        print("Error executing SHOW DATABASES command", e)

# %%
def execute_query(connection, cursor, query, params=None):
    try:
        cursor.execute(query, params)
        if query.strip().lower().startswith('select') or query.strip().lower().startswith('show'):
            result = cursor.fetchall()  # Ensure all results are fetched
            return result
        else:
            connection.commit()
            return cursor.rowcount
    except Error as e:
        print("Error executing query:", e)
        return None

# %%
def put_res(results, query_type="SELECT"):
    if not results:
        print("No results found.")
        return

    if query_type.lower() in ["select", "show"]:
        for row in results:
            print(row)
    else:
        print(f"Affected rows: {results}")

# %%
res = execute_query(con, cur, 'SHOW TABLES', params=None)
put_res(res)
# Out:
# ('events',)
# ('session',)

# %%
show_databases(con)
# Out:
# Databases:
# data_centric
# flight_prediction
# information_schema
# library
# mysql
# performance_schema
# sakila
# scopa
# sys
# villes_france_db
# voiture_db

# %%
def create_database(connection, db_name):
    cursor = None
    try:
        cursor = connection.cursor()
        query = f"SHOW DATABASES LIKE '{db_name}'"
        result = execute_query(connection, cursor, query)
        if result:
            print(f"Database '{db_name}' already exists.")
        else:
            query = f"CREATE DATABASE {db_name}"
            result = execute_query(connection, cursor, query)
            print(f"Database '{db_name}' created successfully.")
            show_databases(connection)
    finally:
        if cursor:
            cursor.close()

# %%
create_database(con, 'flight_prediction')
# Out:
# Error executing query: 1007 (HY000): Can't create database 'flight_prediction'; database exists
# Databases:
# data_centric
# flight_prediction
# information_schema
# library
# mysql
# performance_schema
# sakila
# scopa
# sys
# villes_france_db
# voiture_db

# %%
close_connection(con, cur)
con, cur = connect_to_database('flight_prediction')
# Out:
# MySQL connection is closed
# Connected to MySQL Server version 8.3.0
# You're connected to database: ('flight_prediction',)

# %% [markdown]
# ## sql - create table

# %%
def map_dtype_to_mysql(dtype, smallint=False):
    if pd.api.types.is_integer_dtype(dtype):
        if smallint:
            return "SMALLINT"
        return "INT"
    elif pd.api.types.is_float_dtype(dtype):
        return "FLOAT"
    elif pd.api.types.is_bool_dtype(dtype):
        return "BOOLEAN"
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return "DATETIME"
    else:
        return "VARCHAR(255)"

# %%
columns = df.columns
types = df.dtypes
column_definitions = ", ".join([f"{col} {map_dtype_to_mysql(types[col])}" for col in columns])
column_definitions
# Out:
# 'FL_DATE DATETIME, AIRLINE_ID INT, CARRIER VARCHAR(255), TAIL_NUM VARCHAR(255), FL_NUM INT, ORIGIN_AIRPORT_ID INT, ORIGIN_AIRPORT_SEQ_ID INT, ORIGIN_CITY_MARKET_ID INT, ORIGIN VARCHAR(255), ORIGIN_CITY_NAME VARCHAR(255), ORIGIN_STATE_ABR VARCHAR(255), ORIGIN_STATE_FIPS INT, ORIGIN_STATE_NM VARCHAR(255), ORIGIN_WAC INT, DEST_AIRPORT_ID INT, DEST_AIRPORT_SEQ_ID INT, DEST_CITY_MARKET_ID INT, DEST VARCHAR(255), DEST_CITY_NAME VARCHAR(255), DEST_STATE_ABR VARCHAR(255), DEST_STATE_FIPS INT, DEST_STATE_NM VARCHAR(255), DEST_WAC INT, CRS_DEP_TIME INT, DEP_TIME INT, DEP_DELAY INT, DEP_DELAY_GROUP INT, TAXI_OUT INT, WHEELS_OFF INT, WHEELS_ON INT, TAXI_IN INT, CRS_ARR_TIME INT, ARR_TIME INT, ARR_DELAY INT, ARR_DELAY_GROUP INT, CANCELLED INT, DIVERTED INT, CRS_ELAPSED_TIME INT, ACTUAL_ELAPSED_TIME INT, AIR_TIME INT, DISTANCE INT, DISTANCE_GROUP INT, CARRIER_DELAY INT, WEATHER_DELAY INT, NAS_DELAY INT, SECURITY_DELAY INT, LATE_AIRCRAFT_DELAY INT'

# %%
def create_table_from_dataframe(connection, table_name, dataframe, column_types=None, foreign_keys=None, smallint=False):
    cursor = None
    try:
        cursor = connection.cursor()
        columns = dataframe.columns
        types = dataframe.dtypes

        column_definitions = []
        for col in columns:
            if column_types and col in column_types:
                col_type = column_types[col]
            else:
                col_type = map_dtype_to_mysql(types[col],  smallint=smallint)
            column_definitions.append(f"{col} {col_type}")

        if foreign_keys:
            for col, ref in foreign_keys.items():
                column_definitions.append(f"FOREIGN KEY ({col}) REFERENCES {ref}")

        query = f"CREATE TABLE {table_name} ({', '.join(column_definitions)})"
        result = execute_query(connection, cursor, query)
        print(f"Table '{table_name}' created successfully.")
    finally:
        if cursor:
            cursor.close()

# %%
def insert_dataframe_to_table(connection, table_name, dataframe):
    cursor = None
    try:
        cursor = connection.cursor()
        for _, row in dataframe.iterrows():
            columns = ", ".join(row.index)
            values = ", ".join(["%s"] * len(row))
            # row_values = [None if pd.isna(value) else value for value in row] 
            query = f"INSERT INTO {table_name} ({columns}) VALUES ({values})"
            cursor.execute(query, tuple(row))
            # cursor.execute(query, tuple(row_values))
        connection.commit()
        print(f"Data inserted successfully into '{table_name}' table.")
    except Error as e:
        print("Error inserting data:", e)
    finally:
        if cursor:
            cursor.close()

# %% [markdown]
# ## location

# %%
df_origin = df[[col for col in df.columns if col.startswith('ORIGIN_')]].rename(columns=lambda x: x.replace('ORIGIN_', '')).drop_duplicates()
df_dest = df[[col for col in df.columns if col.startswith('DEST_')]].rename(columns=lambda x: x.replace('DEST_', '')).drop_duplicates()

df_location = pd.concat([df_origin, df_dest], ignore_index=True).drop_duplicates()


df_location
# Out:
#      AIRPORT_ID  AIRPORT_SEQ_ID  CITY_MARKET_ID              CITY_NAME  \
# 0         11298         1129804           30194  Dallas/Fort Worth, TX
# 1         11433         1143302           31295            Detroit, MI
# 2         14747         1474703           30559            Seattle, WA
# 3         12478         1247803           31703           New York, NY
# 4         14831         1483103           32457           San Jose, CA
# ..          ...             ...             ...                    ...
# 317       11495         1149502           31453            Houston, TX
# 318       14082         1408202           34082        Punta Gorda, FL
# 319       14955         1495503           34955             Saipan, TT
# 320       11563         1156303           31563           Wendover, UT
# 321       10990         1099003           30990    Charlottesville, VA
#
#     STATE_ABR  STATE_FIPS                                        STATE_NM  WAC
# 0          TX          48                                           Texas   74
# 1          MI          26                                        Michigan   43
# 2          WA          53                                      Washington   93
# 3          NY          36                                        New York   22
# 4          CA           6                                      California   91
# ..        ...         ...                                             ...  ...
# 317        TX          48                                           Texas   74
# 318        FL          12                                         Florida   33
# 319        TT          75  U.S. Pacific Trust Territories and Possessions    5
# 320        UT          49                                            Utah   87
# 321        VA          51                                        Virginia   38
#
# [322 rows x 8 columns]

# %% [markdown]
# ## location - state

# %%
df_state = df_location[['STATE_ABR', 'STATE_FIPS', 'STATE_NM', 'WAC']].drop_duplicates()
df_state.shape
# Out:
# (52, 4)

# %%
df_state.rename(columns={'STATE_ABR': 'abr', 'STATE_FIPS': 'FIPS', 'STATE_NM': 'name'}, inplace=True)

# %%
df_state
# Out:
#     abr  FIPS                                            name  WAC
# 0    TX    48                                           Texas   74
# 1    MI    26                                        Michigan   43
# 2    WA    53                                      Washington   93
# 3    NY    36                                        New York   22
# 4    CA     6                                      California   91
# 5    IL    17                                        Illinois   41
# 6    AZ     4                                         Arizona   81
# 7    MO    29                                        Missouri   64
# 9    FL    12                                         Florida   33
# 10   CO     8                                        Colorado   82
# 12   HI    15                                          Hawaii    2
# 15   NV    32                                          Nevada   85
# 16   UT    49                                            Utah   87
# 18   VI    78                             U.S. Virgin Islands    4
# 19   MA    25                                   Massachusetts   13
# 25   OK    40                                        Oklahoma   73
# 27   PA    42                                    Pennsylvania   23
# 29   NC    37                                  North Carolina   36
# 30   VA    51                                        Virginia   38
# 32   GA    13                                         Georgia   34
# 37   TN    47                                       Tennessee   54
# 38   WY    56                                         Wyoming   88
# 40   NJ    34                                      New Jersey   21
# 43   PR    72                                     Puerto Rico    3
# 44   NM    35                                      New Mexico   86
# 47   LA    22                                       Louisiana   72
# 51   IN    18                                         Indiana   42
# 52   OR    41                                          Oregon   92
# 53   MD    24                                        Maryland   35
# 54   MN    27                                       Minnesota   63
# 55   WI    55                                       Wisconsin   45
# 60   IA    19                                            Iowa   61
# 63   NE    31                                        Nebraska   65
# 66   KY    21                                        Kentucky   52
# 69   OH    39                                            Ohio   44
# 75   CT     9                                     Connecticut   11
# 79   ID    16                                           Idaho   83
# 82   AK     2                                          Alaska    1
# 86   RI    44                                    Rhode Island   15
# 89   KS    20                                          Kansas   62
# 90   ME    23                                           Maine   12
# 92   SC    45                                  South Carolina   37
# 94   AL     1                                         Alabama   51
# 119  VT    50                                         Vermont   16
# 123  ND    38                                    North Dakota   66
# 128  MS    28                                     Mississippi   53
# 129  MT    30                                         Montana   84
# 149  AR     5                                        Arkansas   71
# 165  SD    46                                    South Dakota   67
# 170  WV    54                                   West Virginia   39
# 172  TT    75  U.S. Pacific Trust Territories and Possessions    5
# 265  NH    33                                   New Hampshire   14

# %%
column_types = {
    'abr': 'VARCHAR(2) PRIMARY KEY',
    'name': 'VARCHAR(100)',
    'FIPS': 'SMALLINT',
    'WAC': 'SMALLINT'
}

table_name = "states"
create_table_from_dataframe(con, table_name, df_state, column_types)
insert_dataframe_to_table(con, table_name, df_state)
# Out:
# Table 'states' created successfully.
# Data inserted successfully into 'states' table.

# %%
# drop_table_query = "DROP TABLE IF EXISTS states"
# execute_query(con, cur, drop_table_query)
# Out:
# 0

# %% [markdown]
# ## location - city

# %%
df_location.nunique()
# Out:
# AIRPORT_ID        313
# AIRPORT_SEQ_ID    322
# CITY_MARKET_ID    291
# CITY_NAME         308
# STATE_ABR          52
# STATE_FIPS         52
# STATE_NM           52
# WAC                52
# dtype: int64

# %%
df_airport = df_location[['AIRPORT_ID', 'AIRPORT_SEQ_ID', 'CITY_MARKET_ID', 'CITY_NAME', 'STATE_ABR']]
df_airport.rename(columns={'AIRPORT_ID': 'airport_ID', 'AIRPORT_SEQ_ID': 'airport_seq_ID','CITY_MARKET_ID': 'city_market_ID', 'CITY_NAME': 'city', 'STATE_ABR': 'state_ID'}, inplace=True)
df_airport
# Out:
# /var/folders/r7/br4v00791394391wmy98wqx40000gn/T/ipykernel_16149/2668265669.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_airport.rename(columns={'AIRPORT_ID': 'airport_ID', 'AIRPORT_SEQ_ID': 'airport_seq_ID','CITY_MARKET_ID': 'city_market_ID', 'CITY_NAME': 'city', 'STATE_ABR': 'state_ID'}, inplace=True)
#      airport_ID  airport_seq_ID  city_market_ID                   city  \
# 0         11298         1129804           30194  Dallas/Fort Worth, TX
# 1         11433         1143302           31295            Detroit, MI
# 2         14747         1474703           30559            Seattle, WA
# 3         12478         1247803           31703           New York, NY
# 4         14831         1483103           32457           San Jose, CA
# ..          ...             ...             ...                    ...
# 317       11495         1149502           31453            Houston, TX
# 318       14082         1408202           34082        Punta Gorda, FL
# 319       14955         1495503           34955             Saipan, TT
# 320       11563         1156303           31563           Wendover, UT
# 321       10990         1099003           30990    Charlottesville, VA
#
#     state_ID
# 0         TX
# 1         MI
# 2         WA
# 3         NY
# 4         CA
# ..       ...
# 317       TX
# 318       FL
# 319       TT
# 320       UT
# 321       VA
#
# [322 rows x 5 columns]

# %%
column_types = {
    'airport_seq_ID': 'INT PRIMARY KEY',
    'city': 'VARCHAR(100)',
    'state_ID': 'VARCHAR(2)' 
}

foreign_keys = {
    'state_ID': 'states(abr)'  # state_ID references states(state_ID)
}

table_name = "airport"
create_table_from_dataframe(con, table_name, df_airport, column_types, foreign_keys)
insert_dataframe_to_table(con, table_name, df_airport)
# Out:
# Table 'airport' created successfully.
# Data inserted successfully into 'airport' table.

# %%
# drop_table_query = "DROP TABLE IF EXISTS airport"
# execute_query(con, cur, drop_table_query)
# Out:
# 0

# %%
# del df_location
# del df_state
# del df_airport

# %% [markdown]
# ## CARRIER

# %%
df.nunique()
# Out:
# FL_DATE                   366
# AIRLINE_ID                 12
# CARRIER                    12
# TAIL_NUM                 5035
# FL_NUM                   6974
# ORIGIN_AIRPORT_ID         313
# ORIGIN_AIRPORT_SEQ_ID     322
# ORIGIN_CITY_MARKET_ID     291
# ORIGIN                    313
# ORIGIN_CITY_NAME          308
# ORIGIN_STATE_ABR           52
# ORIGIN_STATE_FIPS          52
# ORIGIN_STATE_NM            52
# ORIGIN_WAC                 52
# DEST_AIRPORT_ID           310
# DEST_AIRPORT_SEQ_ID       319
# DEST_CITY_MARKET_ID       289
# DEST                      310
# DEST_CITY_NAME            306
# DEST_STATE_ABR             52
# DEST_STATE_FIPS            52
# DEST_STATE_NM              52
# DEST_WAC                   52
# CRS_DEP_TIME             1334
# DEP_TIME                 1440
# DEP_DELAY                1337
# DEP_DELAY_GROUP            15
# TAXI_OUT                  178
# WHEELS_OFF               1440
# WHEELS_ON                1440
# TAXI_IN                   193
# CRS_ARR_TIME             1439
# ARR_TIME                 1440
# ARR_DELAY                1386
# ARR_DELAY_GROUP            15
# CANCELLED                   2
# DIVERTED                    2
# CRS_ELAPSED_TIME          575
# ACTUAL_ELAPSED_TIME       716
# AIR_TIME                  692
# DISTANCE                 1364
# DISTANCE_GROUP             11
# CARRIER_DELAY            1207
# WEATHER_DELAY             688
# NAS_DELAY                 608
# SECURITY_DELAY            172
# LATE_AIRCRAFT_DELAY       749
# dtype: int64

# %%
carrier = df[['AIRLINE_ID', 'CARRIER']].drop_duplicates()
carrier.rename(columns={'AIRLINE_ID': 'airline_ID', 'CARRIER': 'carrier'}, inplace=True)
carrier
# Out:
#         airline_ID carrier
# 0            19805      AA
# 70021        19930      AS
# 84480        20409      B6
# 107857       19790      DL
# 111458       20436      F9
# 115345       19690      HA
# 121804       20416      NK
# 130818       20366      EV
# 133528       20304      OO
# 179805       19977      UA
# 219195       21171      VX
# 336970       19393      WN

# %%
carrier.count()
# Out:
# AIRLINE_ID    12
# CARRIER       12
# dtype: int64

# %%
column_types = {
    'airline_ID': 'INT PRIMARY KEY',
    'carrier': 'VARCHAR(2)' 
}

table_name = "airline"
create_table_from_dataframe(con, table_name, carrier, column_types)
insert_dataframe_to_table(con, table_name, carrier)
# Out:
# Table 'airline' created successfully.
# Data inserted successfully into 'airline' table.

# %% [markdown]
# ### DF to sql

# %%
df = df.reset_index().rename(columns={'index': 'ID'})
df['ID'] = df.index + 1

# %%
df_plane_infos = df[['ID', 'FL_DATE', 'AIRLINE_ID', 'TAIL_NUM', 'FL_NUM', 'ORIGIN_AIRPORT_SEQ_ID', 'DEST_AIRPORT_SEQ_ID', 'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME', 'DISTANCE', 'DISTANCE_GROUP']]
df_delay = df[['ID', 'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_GROUP', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY', 'ARR_DELAY_GROUP', 'CANCELLED', 'DIVERTED', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']]

# %%
df_plane_infos.rename(columns={
    'FL_DATE': 'date',
    'AIRLINE_ID': 'airline_ID',
    'TAIL_NUM': 'tail_num',
    'FL_NUM': 'fl_num',
    'ORIGIN_AIRPORT_SEQ_ID': 'origin_airport_seq_ID',
    'DEST_AIRPORT_SEQ_ID': 'dest_airport_seq_ID',
    'CRS_DEP_TIME': 'dep_time',
    'CRS_ARR_TIME': 'arr_time',
    'CRS_ELAPSED_TIME': 'duration',
    'DISTANCE': 'distance',
    'DISTANCE_GROUP': 'distance_group'
    }, inplace=True)
# Out:
# /var/folders/r7/br4v00791394391wmy98wqx40000gn/T/ipykernel_16149/3324676957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plane_infos.rename(columns={

# %%
df_plane_infos
# Out:
#               ID       date  airline_ID tail_num  fl_num  \
# 0              1 2016-01-06       19805   N4YBAA      43
# 1              2 2016-01-07       19805   N434AA      43
# 2              3 2016-01-08       19805   N541AA      43
# 3              4 2016-01-09       19805   N489AA      43
# 4              5 2016-01-10       19805   N439AA      43
# ...          ...        ...         ...      ...     ...
# 5635962  5635963 2016-12-31       19393   N7703A    1077
# 5635963  5635964 2016-12-31       19393   N7815L    1345
# 5635964  5635965 2016-12-31       19393   N967WN    1176
# 5635965  5635966 2016-12-31       19393   N271LV     865
# 5635966  5635967 2016-12-31       19393   N762SW    6775
#
#          origin_airport_seq_ID  dest_airport_seq_ID  dep_time  arr_time  \
# 0                      1129804              1143302      1100      1438
# 1                      1129804              1143302      1100      1438
# 2                      1129804              1143302      1100      1438
# 3                      1129804              1143302      1100      1438
# 4                      1129804              1143302      1100      1438
# ...                        ...                  ...       ...       ...
# 5635962                1537602              1289204       755       830
# 5635963                1537602              1289204      1320      1355
# 5635964                1537602              1323202       705      1125
# 5635965                1537602              1467903      1220      1235
# 5635966                1537602              1467903       800       820
#
#          duration  distance  distance_group
# 0             158       986               4
# 1             158       986               4
# 2             158       986               4
# 3             158       986               4
# 4             158       986               4
# ...           ...       ...             ...
# 5635962        95       451               2
# 5635963        95       451               2
# 5635964       200      1440               6
# 5635965        75       368               2
# 5635966        80       368               2
#
# [5635967 rows x 12 columns]

# %%
df_plane_infos.isna().sum()
# Out:
# ID                           0
# date                         0
# airline_ID                   0
# tail_num                 12750
# fl_num                       0
# origin_airport_seq_ID        0
# dest_airport_seq_ID          0
# dep_time                     0
# arr_time                     0
# duration                     0
# distance                     0
# distance_group               0
# dtype: int64

# %%
df_delay.rename(columns={
    'FL_DATE': 'date',
    'AIRLINE_ID': 'airline_ID',
    'TAIL_NUM': 'tail_num',
    'FL_NUM': 'fl_num',
    'ORIGIN_AIRPORT_SEQ_ID': 'origin_airport_seq_ID',
    'DEST_AIRPORT_SEQ_ID': 'dest_airport_seq_ID',
    'CRS_DEP_TIME': 'dep_time',
    'CRS_ARR_TIME': 'arr_time',
    'CRS_ELAPSED_TIME': 'duration',
    'DISTANCE': 'distance',
    'DISTANCE_GROUP': 'distance_group'
    }, inplace=True)
# Out:
# /var/folders/r7/br4v00791394391wmy98wqx40000gn/T/ipykernel_16149/2519065013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delay.rename(columns={

# %%
df_delay
# Out:
#               ID  dep_time  dep_delay  dep_delay_group  taxi_out  wheels_off  \
# 0              1      1057         -3               -1        15        1112
# 1              2      1056         -4               -1        14        1110
# 2              3      1055         -5               -1        21        1116
# 3              4      1102          2                0        13        1115
# 4              5      1240        100                6        20        1300
# ...          ...       ...        ...              ...       ...         ...
# 5635962  5635963       747         -8               -1        11         758
# 5635963  5635964      1325          5                0        13        1338
# 5635964  5635965       659         -6               -1         9         708
# 5635965  5635966      1219         -1               -1        10        1229
# 5635966  5635967       758         -2               -1         9         807
#
#          wheels_on  taxi_in  arr_time  arr_delay  arr_delay_group  cancelled  \
# 0             1424        8      1432         -6               -1          0
# 1             1416       10      1426        -12               -1          0
# 2             1431       14      1445          7                0          0
# 3             1424        9      1433         -5               -1          0
# 4             1617       14      1631        113                7          0
# ...            ...      ...       ...        ...              ...        ...
# 5635962        807       10       817        -13               -1          0
# 5635963       1351       13      1404          9                0          0
# 5635964       1051        4      1055        -30               -2          0
# 5635965       1227        4      1231         -4               -1          0
# 5635966        806        5       811         -9               -1          0
#
#          diverted  actual_elapsed_time  air_time  carrier_delay  \
# 0               0                  155       132           <NA>
# 1               0                  150       126           <NA>
# 2               0                  170       135           <NA>
# 3               0                  151       129           <NA>
# 4               0                  171       137              0
# ...           ...                  ...       ...            ...
# 5635962         0                   90        69           <NA>
# 5635963         0                   99        73           <NA>
# 5635964         0                  176       163           <NA>
# 5635965         0                   72        58           <NA>
# 5635966         0                   73        59           <NA>
#
#          weather_delay  nas_delay  security_delay  late_aircraft_delay
# 0                 <NA>       <NA>            <NA>                 <NA>
# 1                 <NA>       <NA>            <NA>                 <NA>
# 2                 <NA>       <NA>            <NA>                 <NA>
# 3                 <NA>       <NA>            <NA>                 <NA>
# 4                    0         47               0                   66
# ...                ...        ...             ...                  ...
# 5635962           <NA>       <NA>            <NA>                 <NA>
# 5635963           <NA>       <NA>            <NA>                 <NA>
# 5635964           <NA>       <NA>            <NA>                 <NA>
# 5635965           <NA>       <NA>            <NA>                 <NA>
# 5635966           <NA>       <NA>            <NA>                 <NA>
#
# [5635967 rows x 20 columns]

# %%
is_datetime = pd.api.types.is_datetime64_any_dtype(df_plane_infos['date'])
print(f"Is 'birthdate' column of datetime type? {is_datetime}")
# Out:
# Is 'birthdate' column of datetime type? True

# %%
df_plane_infos['ID'].nunique()
# Out:
# 5635967

# %%
df_plane_infos[df_plane_infos['ID'] == 80]
# Out:
#     ID       date  airline_ID tail_num  fl_num  origin_airport_seq_ID  \
# 79  80 2016-01-23       19805     None      44                1474703
#
#     dest_airport_seq_ID  dep_time  arr_time  duration  distance  \
# 79              1247803       640      1501       321      2422
#
#     distance_group
# 79              10

# %%
df_plane_infos = df_plane_infos.where(pd.notnull(df_plane_infos), None)

# %%
column_types = {
    'ID': 'INT PRIMARY KEY',
    'tail_num': 'VARCHAR(20)',
    'dep_time': 'SMALLINT',
    'arr_time': 'SMALLINT',
    'duration': 'SMALLINT',
    'distance': 'SMALLINT',
    'distance_group': 'SMALLINT'
}

foreign_keys = {
    'dest_airport_seq_id': 'airport(airport_seq_ID)',
    'origin_airport_seq_id': 'airport(airport_seq_ID)',
    'airline_ID': 'airline(airline_ID)',
}


table_name = "flight"
create_table_from_dataframe(con, table_name, df_plane_infos, column_types, foreign_keys)
insert_dataframe_to_table(con, table_name, df_plane_infos)
# Out:
# Table 'flight' created successfully.
# Data inserted successfully into 'flight' table.

# %%
# drop_table_query = "DROP TABLE IF EXISTS flight"
# execute_query(con, cur, drop_table_query)
# Out:
# 0

# %%
df_delay.nunique()
# Out:
# ID                     5635967
# dep_time                  1440
# dep_delay                 1337
# dep_delay_group             15
# taxi_out                   178
# wheels_off                1440
# wheels_on                 1440
# taxi_in                    193
# arr_time                  1440
# arr_delay                 1386
# arr_delay_group             15
# cancelled                    2
# diverted                     2
# actual_elapsed_time        716
# air_time                   692
# carrier_delay             1207
# weather_delay              688
# nas_delay                  608
# security_delay             172
# late_aircraft_delay        749
# dtype: int64

# %%
df_delay['cancelled'] = df_delay['cancelled'].astype(bool)
df_delay['diverted'] = df_delay['diverted'].astype(bool)
# Out:
# /var/folders/r7/br4v00791394391wmy98wqx40000gn/T/ipykernel_16149/3551294650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delay['cancelled'] = df_delay['cancelled'].astype(bool)
# /var/folders/r7/br4v00791394391wmy98wqx40000gn/T/ipykernel_16149/3551294650.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delay['diverted'] = df_delay['diverted'].astype(bool)

# %%
is_boolean = pd.api.types.is_bool_dtype(df_delay['cancelled'])
print(f"Is 'cancelled' column of boolean type? {is_boolean}")
# Out:
# Is 'cancelled' column of boolean type? True

# %%
columns = df_delay.columns
types = df_delay.dtypes
column_definitions = ", ".join([f"{col} {map_dtype_to_mysql(types[col], smallint=True)}" for col in columns])
column_definitions
# Out:
# 'ID SMALLINT, dep_time SMALLINT, dep_delay SMALLINT, dep_delay_group SMALLINT, taxi_out SMALLINT, wheels_off SMALLINT, wheels_on SMALLINT, taxi_in SMALLINT, arr_time SMALLINT, arr_delay SMALLINT, arr_delay_group SMALLINT, cancelled BOOLEAN, diverted BOOLEAN, actual_elapsed_time SMALLINT, air_time SMALLINT, carrier_delay SMALLINT, weather_delay SMALLINT, nas_delay SMALLINT, security_delay SMALLINT, late_aircraft_delay SMALLINT'

# %%
df_delay
# Out:
#               ID dep_time dep_delay dep_delay_group taxi_out wheels_off  \
# 0              1     1057        -3              -1       15       1112
# 1              2     1056        -4              -1       14       1110
# 2              3     1055        -5              -1       21       1116
# 3              4     1102         2               0       13       1115
# 4              5     1240       100               6       20       1300
# ...          ...      ...       ...             ...      ...        ...
# 5635962  5635963      747        -8              -1       11        758
# 5635963  5635964     1325         5               0       13       1338
# 5635964  5635965      659        -6              -1        9        708
# 5635965  5635966     1219        -1              -1       10       1229
# 5635966  5635967      758        -2              -1        9        807
#
#         wheels_on taxi_in arr_time arr_delay arr_delay_group  cancelled  \
# 0            1424       8     1432        -6              -1      False
# 1            1416      10     1426       -12              -1      False
# 2            1431      14     1445         7               0      False
# 3            1424       9     1433        -5              -1      False
# 4            1617      14     1631       113               7      False
# ...           ...     ...      ...       ...             ...        ...
# 5635962       807      10      817       -13              -1      False
# 5635963      1351      13     1404         9               0      False
# 5635964      1051       4     1055       -30              -2      False
# 5635965      1227       4     1231        -4              -1      False
# 5635966       806       5      811        -9              -1      False
#
#          diverted actual_elapsed_time air_time carrier_delay weather_delay  \
# 0           False                 155      132          None          None
# 1           False                 150      126          None          None
# 2           False                 170      135          None          None
# 3           False                 151      129          None          None
# 4           False                 171      137             0             0
# ...           ...                 ...      ...           ...           ...
# 5635962     False                  90       69          None          None
# 5635963     False                  99       73          None          None
# 5635964     False                 176      163          None          None
# 5635965     False                  72       58          None          None
# 5635966     False                  73       59          None          None
#
#         nas_delay security_delay late_aircraft_delay
# 0            None           None                None
# 1            None           None                None
# 2            None           None                None
# 3            None           None                None
# 4              47              0                  66
# ...           ...            ...                 ...
# 5635962      None           None                None
# 5635963      None           None                None
# 5635964      None           None                None
# 5635965      None           None                None
# 5635966      None           None                None
#
# [5635967 rows x 20 columns]

# %%
df_delay = df_delay.replace({pd.NA: None, np.nan: None})

# %%
column_types = {
    'ID': 'INT PRIMARY KEY',
}

table_name = "delay"
create_table_from_dataframe(con, table_name, df_delay, column_types, smallint=True)
insert_dataframe_to_table(con, table_name, df_delay)
# Out:
# Error executing query: 1050 (42S01): Table 'delay' already exists
# Table 'delay' created successfully.
# Data inserted successfully into 'delay' table.

# %%
# drop_table_query = "DROP TABLE IF EXISTS delay"
# execute_query(con, cur, drop_table_query)

# %%
# 'FL_DATE'
# 'AIRLINE_ID'
# 'TAIL_NUM'
# 'FL_NUM'
# 'ORIGIN_AIRPORT_SEQ_ID'
# 'DEST_AIRPORT_SEQ_ID'
# 'CRS_DEP_TIME'
# 'CRS_ARR_TIME'
# 'CRS_ELAPSED_TIME'
# 'DISTANCE'
# 'DISTANCE_GROUP'

# 'DEP_TIME'
# 'DEP_DELAY'
# 'DEP_DELAY_GROUP'
# 'TAXI_OUT'
# 'WHEELS_OFF'
# 'WHEELS_ON'
# 'TAXI_IN'
# 'ARR_TIME'
# 'ARR_DELAY'
# 'ARR_DELAY_GROUP'
# 'CANCELLED'
# 'DIVERTED'
# 'ACTUAL_ELAPSED_TIME'
# 'AIR_TIME'
# 'CARRIER_DELAY'
# 'WEATHER_DELAY'
# 'NAS_DELAY'
# 'SECURITY_DELAY'
# 'LATE_AIRCRAFT_DELAY'
